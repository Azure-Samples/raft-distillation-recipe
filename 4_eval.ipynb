# %% [markdown]
# # Evaluation of the fine-tuned and baseline models with the RAFT generated eval dataset split
#
# In this notebook, we will use the evaluation dataset synthetically generated in the [](./1_gen.ipynb) notebook using the RAFT method to evaluate both the baseline model and the fine-tuned model, then compare the two to analyse the impact of the fine-tuning.
#
# We introduce the `promptflow-evals` package and built-in evaluators. Then, we'll demonstrate how to use the `evaluate` API to assess data using these evaluators.
#
# Finally, we'll draw a diagram showing the performance of the fine-tuned model against the baseline.
#
# ## Overview
#
# - Testing
#   - Run the baseline model on the evaluation split to get its predictions.
#   - Run the finetuned model on the evaluation split to get its predictions.
# - Answers formatting
#   - Convert the baseline model answers to a format suitable for testing
#   - Convert the fine-tuned model answers to a format suitable for testing
# - Evaluation
#   - Calculate the metrics (such as accuracy, precision, recall, etc.) based on the predictions from the baseline model.
#   - Calculate the metrics based on the predictions from the finetuned model.
# - Compare metrics

# %% [markdown]
# ## Installing requirements
#
# The requirements should have been automatically installed if you opened the project in Dev Container or Codespaces, but if not, uncomment the following cell to install the requirements

# %%
#! pip install promptflow-evals

# %% [markdown]
# ## Running time and cost
#
# The RAFT evaluation script usually takes a few minutes on the default sample document but can take days on bigger domains depending on the number and size of documents and the number of questions being generated for each chunk.
#
# The cost of running this RAFT script on the sample document should be a few dollars. But beware, running it on bigger domains can cost hundreds of dollars if not more.

# %% [markdown]
# ## Testing
#
# ### Define variables we will need

# %%
import os
from dotenv import load_dotenv

# User provided values
load_dotenv(".env")

# Variables passed by previous notebooks
load_dotenv(".env.state")

# Let's capture the initial working directory because the evaluate function will change it
dir = os.getcwd()

experiment_name = os.getenv("DATASET_NAME")
experiment_dir = f"{dir}/dataset/{experiment_name}-files"

# Dataset generated by the gen notebook that we will evaluate the baseline and finetuned models on
dataset_path_hf_eval = f"{experiment_dir}/{experiment_name}-hf.eval.jsonl"

# Evaluated answer files
dataset_path_hf_eval_answer = f"{experiment_dir}/{experiment_name}-hf.eval.answer.jsonl"
dataset_path_hf_eval_answer_baseline = f"{experiment_dir}/{experiment_name}-hf.eval.answer.baseline.jsonl"

# Formatted answer evaluation files
dataset_path_eval_answer_finetuned = f"{experiment_dir}/{experiment_name}-eval.answer.finetuned.jsonl"
dataset_path_eval_answer_baseline = f"{experiment_dir}/{experiment_name}-eval.answer.baseline.jsonl"

# Scored answer files
dataset_path_eval_answer_score_finetuned = f"{experiment_dir}/{experiment_name}-eval.answer.score.finetuned.jsonl"
dataset_path_eval_answer_score_baseline = f"{experiment_dir}/{experiment_name}-eval.answer.score.baseline.jsonl"

BASELINE_OPENAI_DEPLOYMENT = os.getenv("BASELINE_OPENAI_DEPLOYMENT")
FINETUNED_OPENAI_DEPLOYMENT = os.getenv("FINETUNED_OPENAI_DEPLOYMENT")
FINETUNED_MODEL_FORMAT = os.getenv("FINETUNED_MODEL_FORMAT")

print(f"Evaluating the finetuned {FINETUNED_MODEL_FORMAT} model {FINETUNED_OPENAI_DEPLOYMENT} against the baseline model {BASELINE_OPENAI_DEPLOYMENT}")
# Out:
# Evaluating the finetuned chat model ft-job-finetune-registered-3838 against the baseline model raft-baseline-llama-2-7b-chat

# %% [markdown]
# ### Run the baseline model on the evaluation split

# %%
# !env $(cat .env .env.state) python .gorilla/raft/eval.py \
    --question-file $dataset_path_hf_eval \
    --answer-file $dataset_path_hf_eval_answer_baseline \
    --model $BASELINE_OPENAI_DEPLOYMENT \
    --env-prefix BASELINE \
    --mode chat
# Out:
# cat: .env: No such file or directory
# 2024-09-13 17:22:51  INFO [    ] eval Using model: raft-baseline-llama-2-7b-chat
# 2024-09-13 17:22:51  INFO [    ] eval Using mode: chat
# 2024-09-13 17:22:51  INFO [    ] eval Using prompt key: instruction
# 2024-09-13 17:22:51  INFO [    ] eval Using answer key: answer
# 2024-09-13 17:22:51  INFO [    ] env_config Resolved OpenAI env vars with 'BASELINE' prefix:
# 2024-09-13 17:22:51  INFO [    ] env_config  - OPENAI_TYPE=azure
# 2024-09-13 17:22:51  INFO [    ] env_config  - OPENAI_BASE_URL=https://raft-baseline-llama-2-7b-chat.westus3.models.ai.azure.com
# 2024-09-13 17:22:51  INFO [    ] env_config  - OPENAI_DEPLOYMENT=raft-baseline-llama-2-7b-chat
# 2024-09-13 17:22:51  INFO [    ] env_config  - OPENAI_API_KEY=............................bK4V
# 2024-09-13 17:22:52  INFO [    ] eval Removing existing file: /workspaces/llama-raft-recipe/dataset/surfing-1k-files/surfing-1k-hf.eval.answer.baseline.jsonl
# 2024-09-13 17:22:52  INFO [    ] eval Reading questions from: /workspaces/llama-raft-recipe/dataset/surfing-1k-files/surfing-1k-hf.eval.jsonl
# 2024-09-13 17:22:52  INFO [    ] eval Number of questions: 125
# 100%|█| 125/125 [00:58<00:00,  2.12answers/s, last tok/s=6.91e+5, avg tok/s=1.48
# 2024-09-13 17:23:50  INFO [    ] eval Wrote evaluation results to /workspaces/llama-raft-recipe/dataset/surfing-1k-files/surfing-1k-hf.eval.answer.baseline.jsonl
# 2024-09-13 17:23:50  INFO [    ] eval total time used: 58.82734560966492

# %%
import pandas as pd
pd.read_json(dataset_path_hf_eval_answer_baseline, lines=True).head(2)
# Out:
#                                      id     type  \
# 0  06d347e6-9663-4a8d-a5c2-148ddfce46e1  general
# 1  98c2b7cd-1026-4eff-9cf1-3afebb73e552  general
#
#                                             question  \
# 0  What type of surfing focuses on elegance and d...
# 1  Is the emerging material lighter than traditio...
#
#                                              context  \
# 0  {'sentences': [['Done for both exhibition and ...
# 1  {'sentences': [['An emerging board material is...
#
#                                       oracle_context  \
# 0  Done for both exhibition and competitionsthe g...
# 1  An emerging board material is epoxy resinand E...
#
#                                           cot_answer  \
# 0  To answer the question, we need to identify th...
# 1  To answer the question, we need to determine i...
#
#                                          instruction  \
# 0  <DOCUMENT>Done for both exhibition and competi...
# 1  <DOCUMENT>An emerging board material is epoxy ...
#
#                                               answer
# 0  Based on the text, it appears that the type of...
# 1  Yes, according to the text, the emerging mater...

# %% [markdown]
# ### Run the fine tuned model on the evaluation split

# %%
# !env $(cat .env .env.state) python .gorilla/raft/eval.py \
    --question-file $dataset_path_hf_eval \
    --answer-file $dataset_path_hf_eval_answer \
    --model $FINETUNED_OPENAI_DEPLOYMENT \
    --env-prefix FINETUNED \
    --mode $FINETUNED_MODEL_FORMAT
# Out:
# cat: .env: No such file or directory
# 2024-09-13 17:34:40  INFO [    ] eval Using model: ft-job-finetune-registered-3838
# 2024-09-13 17:34:40  INFO [    ] eval Using mode: chat
# 2024-09-13 17:34:40  INFO [    ] eval Using prompt key: instruction
# 2024-09-13 17:34:40  INFO [    ] eval Using answer key: answer
# 2024-09-13 17:34:40  INFO [    ] env_config Resolved OpenAI env vars with 'FINETUNED' prefix:
# 2024-09-13 17:34:40  INFO [    ] env_config  - OPENAI_TYPE=azure
# 2024-09-13 17:34:40  INFO [    ] env_config  - OPENAI_API_KEY=............................uwnu
# 2024-09-13 17:34:40  INFO [    ] env_config  - OPENAI_DEPLOYMENT=ft-job-finetune-registered-3838
# 2024-09-13 17:34:40  INFO [    ] env_config  - OPENAI_BASE_URL=https://ft-job-finetune-registered-3838.westus3.models.ai.azure.com
# 2024-09-13 17:34:40  INFO [    ] eval Removing existing file: /workspaces/llama-raft-recipe/dataset/surfing-1k-files/surfing-1k-hf.eval.answer.jsonl
# 2024-09-13 17:34:40  INFO [    ] eval Reading questions from: /workspaces/llama-raft-recipe/dataset/surfing-1k-files/surfing-1k-hf.eval.jsonl
# 2024-09-13 17:34:40  INFO [    ] eval Number of questions: 125
# 100%|█| 125/125 [03:22<00:00,  1.62s/answers, last tok/s=8.26e+6, avg tok/s=1.93
# 2024-09-13 17:38:03  INFO [    ] eval Wrote evaluation results to /workspaces/llama-raft-recipe/dataset/surfing-1k-files/surfing-1k-hf.eval.answer.jsonl
# 2024-09-13 17:38:03  INFO [    ] eval total time used: 202.68701076507568

# %%
import pandas as pd
pd.read_json(dataset_path_hf_eval_answer, lines=True).head(2)
# Out:
#                                      id     type  \
# 0  98c2b7cd-1026-4eff-9cf1-3afebb73e552  general
# 1  06d347e6-9663-4a8d-a5c2-148ddfce46e1  general
#
#                                             question  \
# 0  Is the emerging material lighter than traditio...
# 1  What type of surfing focuses on elegance and d...
#
#                                              context  \
# 0  {'sentences': [['An emerging board material is...
# 1  {'sentences': [['Done for both exhibition and ...
#
#                                       oracle_context  \
# 0  An emerging board material is epoxy resinand E...
# 1  Done for both exhibition and competitionsthe g...
#
#                                           cot_answer  \
# 0  To answer the question, we need to determine i...
# 1  To answer the question, we need to identify th...
#
#                                          instruction  \
# 0  <DOCUMENT>An emerging board material is epoxy ...
# 1  <DOCUMENT>Done for both exhibition and competi...
#
#                                               answer
# 0  To answer the question, we need to identify wh...
# 1  To answer the question, we need to identify th...

# %% [markdown]
# ## Answers formatting

# %% [markdown]
# ### Format baseline answers
#
# Convert the baseline model answers to a format suitable for testing

# %%
! python .gorilla/raft/format.py \
    --input $dataset_path_hf_eval_answer_baseline \
    --input-type jsonl \
    --output $dataset_path_eval_answer_baseline \
    --output-format eval
# Out:
# 2024-09-13 17:39:15  INFO [    ] raft Dataset has 125 rows
# 2024-09-13 17:39:15  INFO [    ] raft Converting jsonl file /workspaces/llama-raft-recipe/dataset/surfing-1k-files/surfing-1k-hf.eval.answer.baseline.jsonl to jsonl eval file /workspaces/llama-raft-recipe/dataset/surfing-1k-files/surfing-1k-eval.answer.baseline.jsonl
# Creating json from Arrow format: 100%|███████████| 1/1 [00:00<00:00, 174.52ba/s]

# %% [markdown]
# ### Format finetuned model answers
#
# Convert the fine-tuned model answers to a format suitable for testing

# %%
! python .gorilla/raft/format.py \
    --input $dataset_path_hf_eval_answer \
    --input-type jsonl \
    --output $dataset_path_eval_answer_finetuned \
    --output-format eval
# Out:
# Generating train split: 125 examples [00:00, 14493.90 examples/s]
# 2024-09-13 17:39:18  INFO [    ] raft Dataset has 125 rows
# 2024-09-13 17:39:18  INFO [    ] raft Converting jsonl file /workspaces/llama-raft-recipe/dataset/surfing-1k-files/surfing-1k-hf.eval.answer.jsonl to jsonl eval file /workspaces/llama-raft-recipe/dataset/surfing-1k-files/surfing-1k-eval.answer.finetuned.jsonl
# Filter out empty examples: 100%|█████| 125/125 [00:00<00:00, 7838.30 examples/s]
# Map: 100%|███████████████████████████| 125/125 [00:00<00:00, 3480.89 examples/s]
# Map: 100%|███████████████████████████| 125/125 [00:00<00:00, 8434.90 examples/s]
# Map: 100%|███████████████████████████| 125/125 [00:00<00:00, 8320.31 examples/s]
# Creating json from Arrow format: 100%|███████████| 1/1 [00:00<00:00, 235.23ba/s]

# %% [markdown]
# ## Let's review the formatted files

# %% [markdown]
# ### Finetuned model answers

# %%
import pandas as pd

# %%
pd.read_json(dataset_path_eval_answer_finetuned, lines=True).head(2)
# Out:
#                                             question  \
# 0  Is the emerging material lighter than traditio...
# 1  What type of surfing focuses on elegance and d...
#
#                                               answer  gold_final_answer  \
# 0  To answer the question, we need to identify wh...                Yes
# 1  To answer the question, we need to identify th...  Longboard surfing
#
#          final_answer                                            context
# 0                 Yes  <DOCUMENT>An emerging board material is epoxy ...
# 1  Exhibition surfing  <DOCUMENT>Done for both exhibition and competi...

# %% [markdown]
# ### Baseline model answers

# %%
pd.read_json(dataset_path_eval_answer_baseline, lines=True).head(2)
# Out:
#                                             question  \
# 0  What type of surfing focuses on elegance and d...
# 1  Is the emerging material lighter than traditio...
#
#                                               answer  gold_final_answer  \
# 0  Based on the text, it appears that the type of...  Longboard surfing
# 1  Yes, according to the text, the emerging mater...                Yes
#
#                                         final_answer  \
# 0  Based on the text, it appears that the type of...
# 1  Yes, according to the text, the emerging mater...
#
#                                              context
# 0  <DOCUMENT>Done for both exhibition and competi...
# 1  <DOCUMENT>An emerging board material is epoxy ...

# %% [markdown]
# ## Evaluation
#
# ### Built-in Evaluators
#
# The table below lists all the built-in evaluators we support. In the following sections, we will select a few of these evaluators to demonstrate how to use them.
#
# | Category       | Namespace                                        | Evaluator Class           | Notes                                             |
# |----------------|--------------------------------------------------|---------------------------|---------------------------------------------------|
# | Quality        | promptflow.evals.evaluators                      | GroundednessEvaluator     | Measures how well the answer is entailed by the context and is not hallucinated |
# |                |                                                  | RelevanceEvaluator        | How well the answer addresses the main aspects of the question, based on the context. Consider whether all and only the important aspects are contained in the answer when evaluating relevance. |
# |                |                                                  | CoherenceEvaluator        | How well all the sentences fit together and sound naturally as a whole. |
# |                |                                                  | FluencyEvaluator          | Quality of individual sentences in the answer, and whether they are well-written and grammatically correct. |
# |                |                                                  | SimilarityEvaluator       | Measures the similarity between the predicted answer and the correct answer |
# |                |                                                  | F1ScoreEvaluator          | F1 score |
# | Content Safety | promptflow.evals.evaluators.content_safety       | ViolenceEvaluator         |                                                   |
# |                |                                                  | SexualEvaluator           |                                                   |
# |                |                                                  | SelfHarmEvaluator         |                                                   |
# |                |                                                  | HateUnfairnessEvaluator   |                                                   |
# | Composite      | promptflow.evals.evaluators                      | QAEvaluator               | Built on top of individual quality evaluators.    |
# |                |                                                  | ChatEvaluator             | Similar to QAEvaluator but designed for evaluating chat messages. |
# |                |                                                  | ContentSafetyEvaluator    | Built on top of individual content safety evaluators. |

# %% [markdown]
# #### Quality Evaluator

# %%
import os
from promptflow.core import AzureOpenAIModelConfiguration

azure_endpoint = os.environ.get("SCORING_AZURE_OPENAI_ENDPOINT")
azure_deployment = os.environ.get("SCORING_AZURE_OPENAI_DEPLOYMENT")
api_key = os.environ.get("SCORING_AZURE_OPENAI_API_KEY")
api_version = os.environ.get("SCORING_OPENAI_API_VERSION")

print(f"azure_endpoint={azure_endpoint}")
print(f"azure_deployment={azure_deployment}")
print(f"api_version={api_version}")

# Initialize Azure OpenAI Connection
model_config = AzureOpenAIModelConfiguration(
    azure_endpoint=azure_endpoint,
    azure_deployment=azure_deployment,
    api_version=api_version,
    api_key=api_key
)
# Out:
# azure_endpoint=https://aoai-otgsljc2twqys.openai.azure.com/
# azure_deployment=gpt-4
# api_version=2023-07-01-preview

# %%
from promptflow.evals.evaluators import RelevanceEvaluator, SimilarityEvaluator, GroundednessEvaluator

# Initializing evaluators
similarity = SimilarityEvaluator(model_config)
groundedness = GroundednessEvaluator(model_config)

# %%
df = pd.read_json(dataset_path_eval_answer_finetuned, lines=True)
sample = df.iloc[1]
sample
# Out:
# question             What type of surfing focuses on elegance and d...
# answer               To answer the question, we need to identify th...
# gold_final_answer                                    Longboard surfing
# final_answer                                        Exhibition surfing
# context              <DOCUMENT>Done for both exhibition and competi...
# Name: 1, dtype: object

# %%
# Running Groundedness Evaluator on single input row
groundedness_score = groundedness(
    answer=sample["final_answer"],
    context=sample["context"],
)
print(groundedness_score)
# Out:
# {'gpt_groundedness': 3.0}

# %%
# Running Similarity Evaluator on single input row
similarity_score = similarity(
    question=sample["question"],
    answer=sample["final_answer"],
    context=sample["context"],
    ground_truth=sample["gold_final_answer"],
)
print(similarity_score)
# Out:
# {'gpt_similarity': 2.0}

# %% [markdown]
# ### Using the Evaluate API to calculate the metrics

# %% [markdown]
# In previous sections, we walked you through how to use built-in evaluators to evaluate a single row and how to define your own custom evaluators. Now, we will show you how to use these evaluators with the powerful `evaluate` API to assess an entire dataset.

# %% [markdown]
# ### Running the metrics

# %% [markdown]
# Now, we will invoke the `evaluate` API using a few evaluators that we already initialized
#
# Additionally, we have a column mapping to map the `truth` column from the dataset to `ground_truth`, which is accepted by the evaluator.

# %%
from promptflow.evals.evaluate import evaluate

def score_dataset(dataset, output_path=None):
    result = evaluate(
        data=dataset,
        evaluators={"similarity": similarity, "groundedness": groundedness},
        # column mapping
        evaluator_config={
            "similarity": {
                "question": "${data.question}",
                "answer": "${data.final_answer}",
                "ground_truth": "${data.gold_final_answer}",
                "context": "${data.context}",
            },
            "groundedness": {
                "answer": "${data.final_answer}",
                "context": "${data.context}",
            },
        },
    )

    if output_path:
        pd.DataFrame.from_dict(result["rows"]).to_json(output_path, orient="records", lines=True)

    return result

# %% [markdown]
# #### Baseline model evaluation metrics

# %%
pd.read_json(dataset_path_eval_answer_baseline, lines=True).head(2)
# Out:
#                                             question  \
# 0  What type of surfing focuses on elegance and d...
# 1  Is the emerging material lighter than traditio...
#
#                                               answer  gold_final_answer  \
# 0  Based on the text, it appears that the type of...  Longboard surfing
# 1  Yes, according to the text, the emerging mater...                Yes
#
#                                         final_answer  \
# 0  Based on the text, it appears that the type of...
# 1  Yes, according to the text, the emerging mater...
#
#                                              context
# 0  <DOCUMENT>Done for both exhibition and competi...
# 1  <DOCUMENT>An emerging board material is epoxy ...

# %%
baseline_result = score_dataset(dataset_path_eval_answer_baseline, dataset_path_eval_answer_score_baseline)
from IPython.display import display, JSON

display(JSON(baseline_result["metrics"]))
# Out:
# Starting prompt flow service...
# Starting prompt flow service...
# Start prompt flow service on 127.0.0.1:23333, version: 1.14.0.
# Start prompt flow service on 127.0.0.1:23333, version: 1.14.0.
# [2024-09-13 17:40:30 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2024-09-13 17:40:30 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2024-09-13 17:40:30 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run promptflow_evals_evaluators_similarity_similarity_similarityevaluator_9cjux5yq_20240913_174028_147971, log path: /home/vscode/.promptflow/.runs/promptflow_evals_evaluators_similarity_similarity_similarityevaluator_9cjux5yq_20240913_174028_147971/logs.txt
# [2024-09-13 17:40:30 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run promptflow_evals_evaluators_groundedness_groundedness_groundednessevaluator_6r9mrsap_20240913_174028_149507, log path: /home/vscode/.promptflow/.runs/promptflow_evals_evaluators_groundedness_groundedness_groundednessevaluator_6r9mrsap_20240913_174028_149507/logs.txt
# You can stop the prompt flow service with the following command:'pf service stop'.
#
# You can stop the prompt flow service with the following command:'pf service stop'.
#
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=promptflow_evals_evaluators_similarity_similarity_similarityevaluator_9cjux5yq_20240913_174028_147971
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=promptflow_evals_evaluators_groundedness_groundedness_groundednessevaluator_6r9mrsap_20240913_174028_149507
# [2024-09-13 17:40:32 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:40:32 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:40:32 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:40:32 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:40:32 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:40:32 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:40:32 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:40:32 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:40:32 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:40:32 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:40:32 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:40:32 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:40:32 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:40:32 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:40:32 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:40:32 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:40:42 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:40:42 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:40:42 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:40:42 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:40:42 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:40:42 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:40:42 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:40:42 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:40:42 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:40:42 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:40:42 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:40:42 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:40:42 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:40:42 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:40:42 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:40:42 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:41:33 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:41:33 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:41:33 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:41:33 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:41:33 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:41:33 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:41:33 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:41:33 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:41:33 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:41:33 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:41:33 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:41:33 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:41:33 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:41:33 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:41:33 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:41:33 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:41:43 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:41:43 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:41:43 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:41:43 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:41:43 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:41:43 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:41:43 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:41:43 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:41:43 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:41:43 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:41:43 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:41:43 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:41:43 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:41:43 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:41:43 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:41:43 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:42:34 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:42:34 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:42:34 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:42:34 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:42:34 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:42:34 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:42:34 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:42:34 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:42:34 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:42:34 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:42:34 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:42:34 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:42:34 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:42:34 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:42:34 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:42:34 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:42:44 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:42:44 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:42:44 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:42:44 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:42:44 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:42:44 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:42:44 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:42:44 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:42:44 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:42:44 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:42:44 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:42:44 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:42:44 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:42:44 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:42:44 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:42:44 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:43:34 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:43:34 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:43:34 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:43:34 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:43:35 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:43:35 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:43:35 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:43:35 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:43:35 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:43:35 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:43:35 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:43:35 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:43:35 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:43:35 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:43:35 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:43:35 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:43:45 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:43:45 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:43:45 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:43:45 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:43:45 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:43:45 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:43:45 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:43:45 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:43:45 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:43:45 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:43:45 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:43:45 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:43:45 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:43:45 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:43:45 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:43:45 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:44:35 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 60 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:44:35 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #2, Retry-After=60, Back off 60.0 seconds for retry.
# [2024-09-13 17:44:35 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:44:35 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:44:35 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:44:35 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:44:35 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:44:35 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:44:35 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:44:35 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:44:35 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:44:35 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:44:35 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:44:35 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:44:35 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:44:35 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 17:44:45 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:44:45 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:44:45 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:44:45 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:44:45 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:44:45 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 17:44:45 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 17:44:45 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# ...
# 2024-09-13 18:06:31 +0000   52105 execution.bulk     INFO     [Process Pool] [Active processes: 4 / 4]
# 2024-09-13 18:06:31 +0000   52105 execution.bulk     INFO     [Lines] [Finished: 93] [Processing: 4] [Pending: 28]
# 2024-09-13 18:06:31 +0000   52105 execution.bulk     INFO     Processing Lines: line 88 (Process name(ForkProcess-3:3)-Process id(56258)-Line number(88)), line 94 (Process name(ForkProcess-3:1)-Process id(56247)-Line number(94)), line 95 (Process name(ForkProcess-3:4)-Process id(56265)-Line number(95)), line 96 (Process name(ForkProcess-3:2)-Process id(56252)-Line number(96)).
# 2024-09-13 18:06:58 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:1)-Process id(56247)-Line number(94) completed.
# 2024-09-13 18:06:58 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:1)-Process id(56247)-Line number(97) start execution.
# 2024-09-13 18:06:58 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:4)-Process id(56265)-Line number(95) completed.
# 2024-09-13 18:06:58 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:4)-Process id(56265)-Line number(98) start execution.
# 2024-09-13 18:06:58 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:2)-Process id(56252)-Line number(96) completed.
# 2024-09-13 18:06:58 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:2)-Process id(56252)-Line number(99) start execution.
# 2024-09-13 18:06:58 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:3)-Process id(56258)-Line number(88) completed.
# 2024-09-13 18:06:58 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:3)-Process id(56258)-Line number(100) start execution.
# 2024-09-13 18:07:31 +0000   52105 execution.bulk     INFO     [Process Pool] [Active processes: 4 / 4]
# 2024-09-13 18:07:31 +0000   52105 execution.bulk     INFO     [Lines] [Finished: 97] [Processing: 4] [Pending: 24]
# 2024-09-13 18:07:31 +0000   52105 execution.bulk     INFO     Processing Lines: line 97 (Process name(ForkProcess-3:1)-Process id(56247)-Line number(97)), line 98 (Process name(ForkProcess-3:4)-Process id(56265)-Line number(98)), line 99 (Process name(ForkProcess-3:2)-Process id(56252)-Line number(99)), line 100 (Process name(ForkProcess-3:3)-Process id(56258)-Line number(100)).
# 2024-09-13 18:07:59 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:1)-Process id(56247)-Line number(97) completed.
# 2024-09-13 18:07:59 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:1)-Process id(56247)-Line number(101) start execution.
# 2024-09-13 18:07:59 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:4)-Process id(56265)-Line number(98) completed.
# 2024-09-13 18:07:59 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:4)-Process id(56265)-Line number(102) start execution.
# 2024-09-13 18:08:31 +0000   52105 execution.bulk     INFO     [Process Pool] [Active processes: 4 / 4]
# 2024-09-13 18:08:31 +0000   52105 execution.bulk     INFO     [Lines] [Finished: 99] [Processing: 4] [Pending: 22]
# 2024-09-13 18:08:31 +0000   52105 execution.bulk     INFO     Processing Lines: line 99 (Process name(ForkProcess-3:2)-Process id(56252)-Line number(99)), line 100 (Process name(ForkProcess-3:3)-Process id(56258)-Line number(100)), line 101 (Process name(ForkProcess-3:1)-Process id(56247)-Line number(101)), line 102 (Process name(ForkProcess-3:4)-Process id(56265)-Line number(102)).
# 2024-09-13 18:08:59 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:1)-Process id(56247)-Line number(101) completed.
# 2024-09-13 18:08:59 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:1)-Process id(56247)-Line number(103) start execution.
# 2024-09-13 18:08:59 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:4)-Process id(56265)-Line number(102) completed.
# 2024-09-13 18:08:59 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:4)-Process id(56265)-Line number(104) start execution.
# 2024-09-13 18:08:59 +0000   52105 execution.bulk     INFO     Finished 101 / 125 lines.
# 2024-09-13 18:08:59 +0000   52105 execution.bulk     INFO     Average execution time for completed lines: 16.92 seconds. Estimated time for incomplete lines: 406.08 seconds.
# 2024-09-13 18:08:59 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:1)-Process id(56247)-Line number(103) completed.
# 2024-09-13 18:08:59 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:1)-Process id(56247)-Line number(105) start execution.
# 2024-09-13 18:08:59 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:4)-Process id(56265)-Line number(104) completed.
# 2024-09-13 18:08:59 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:4)-Process id(56265)-Line number(106) start execution.
# 2024-09-13 18:09:31 +0000   52105 execution.bulk     INFO     [Process Pool] [Active processes: 4 / 4]
# 2024-09-13 18:09:31 +0000   52105 execution.bulk     INFO     [Lines] [Finished: 103] [Processing: 4] [Pending: 18]
# 2024-09-13 18:09:31 +0000   52105 execution.bulk     INFO     Processing Lines: line 99 (Process name(ForkProcess-3:2)-Process id(56252)-Line number(99)), line 100 (Process name(ForkProcess-3:3)-Process id(56258)-Line number(100)), line 105 (Process name(ForkProcess-3:1)-Process id(56247)-Line number(105)), line 106 (Process name(ForkProcess-3:4)-Process id(56265)-Line number(106)).
# 2024-09-13 18:09:59 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:1)-Process id(56247)-Line number(105) completed.
# 2024-09-13 18:09:59 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:1)-Process id(56247)-Line number(107) start execution.
# 2024-09-13 18:09:59 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:1)-Process id(56247)-Line number(107) completed.
# 2024-09-13 18:09:59 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:1)-Process id(56247)-Line number(108) start execution.
# 2024-09-13 18:09:59 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:3)-Process id(56258)-Line number(100) completed.
# 2024-09-13 18:09:59 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:3)-Process id(56258)-Line number(109) start execution.
# 2024-09-13 18:09:59 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:2)-Process id(56252)-Line number(99) completed.
# 2024-09-13 18:09:59 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:2)-Process id(56252)-Line number(110) start execution.
# 2024-09-13 18:10:09 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:4)-Process id(56265)-Line number(106) completed.
# 2024-09-13 18:10:09 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:4)-Process id(56265)-Line number(111) start execution.
# 2024-09-13 18:10:31 +0000   52105 execution.bulk     INFO     [Process Pool] [Active processes: 4 / 4]
# 2024-09-13 18:10:31 +0000   52105 execution.bulk     INFO     [Lines] [Finished: 108] [Processing: 4] [Pending: 13]
# 2024-09-13 18:10:31 +0000   52105 execution.bulk     INFO     Processing Lines: line 108 (Process name(ForkProcess-3:1)-Process id(56247)-Line number(108)), line 109 (Process name(ForkProcess-3:3)-Process id(56258)-Line number(109)), line 110 (Process name(ForkProcess-3:2)-Process id(56252)-Line number(110)), line 111 (Process name(ForkProcess-3:4)-Process id(56265)-Line number(111)).
# 2024-09-13 18:11:00 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:1)-Process id(56247)-Line number(108) completed.
# 2024-09-13 18:11:00 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:1)-Process id(56247)-Line number(112) start execution.
# 2024-09-13 18:11:00 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:4)-Process id(56265)-Line number(111) completed.
# 2024-09-13 18:11:00 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:4)-Process id(56265)-Line number(113) start execution.
# 2024-09-13 18:11:00 +0000   52105 execution.bulk     INFO     Finished 110 / 125 lines.
# 2024-09-13 18:11:00 +0000   52105 execution.bulk     INFO     Average execution time for completed lines: 16.64 seconds. Estimated time for incomplete lines: 249.6 seconds.
# 2024-09-13 18:11:09 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:3)-Process id(56258)-Line number(109) completed.
# 2024-09-13 18:11:09 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:3)-Process id(56258)-Line number(114) start execution.
# 2024-09-13 18:11:10 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:2)-Process id(56252)-Line number(110) completed.
# 2024-09-13 18:11:10 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:2)-Process id(56252)-Line number(115) start execution.
# 2024-09-13 18:11:31 +0000   52105 execution.bulk     INFO     [Process Pool] [Active processes: 4 / 4]
# 2024-09-13 18:11:31 +0000   52105 execution.bulk     INFO     [Lines] [Finished: 112] [Processing: 4] [Pending: 9]
# 2024-09-13 18:11:31 +0000   52105 execution.bulk     INFO     Processing Lines: line 112 (Process name(ForkProcess-3:1)-Process id(56247)-Line number(112)), line 113 (Process name(ForkProcess-3:4)-Process id(56265)-Line number(113)), line 114 (Process name(ForkProcess-3:3)-Process id(56258)-Line number(114)), line 115 (Process name(ForkProcess-3:2)-Process id(56252)-Line number(115)).
# 2024-09-13 18:12:00 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:3)-Process id(56258)-Line number(114) completed.
# 2024-09-13 18:12:00 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:3)-Process id(56258)-Line number(116) start execution.
# 2024-09-13 18:12:00 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:2)-Process id(56252)-Line number(115) completed.
# 2024-09-13 18:12:00 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:2)-Process id(56252)-Line number(117) start execution.
# 2024-09-13 18:12:01 +0000   56253 execution.bulk     INFO     The process [56253] has received a terminate signal.
# 2024-09-13 18:12:01 +0000   56294 execution.bulk     INFO     The process [56294] has received a terminate signal.
# 2024-09-13 18:12:01 +0000   56284 execution.bulk     INFO     The process [56284] has received a terminate signal.
# 2024-09-13 18:12:01 +0000   56271 execution.bulk     INFO     The process [56271] has received a terminate signal.
# 2024-09-13 18:12:01 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:3)-Process id(56258)-Line number(116) completed.
# 2024-09-13 18:12:01 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:3)-Process id(56258)-Line number(118) start execution.
# 2024-09-13 18:12:01 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:2)-Process id(56252)-Line number(117) completed.
# 2024-09-13 18:12:01 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:2)-Process id(56252)-Line number(119) start execution.
# 2024-09-13 18:12:01 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:1)-Process id(56247)-Line number(112) completed.
# 2024-09-13 18:12:01 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:1)-Process id(56247)-Line number(120) start execution.
# 2024-09-13 18:12:11 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:4)-Process id(56265)-Line number(113) completed.
# 2024-09-13 18:12:11 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:4)-Process id(56265)-Line number(121) start execution.
# 2024-09-13 18:12:31 +0000   52105 execution.bulk     INFO     [Process Pool] [Active processes: 4 / 4]
# 2024-09-13 18:12:31 +0000   52105 execution.bulk     INFO     [Lines] [Finished: 118] [Processing: 4] [Pending: 3]
# 2024-09-13 18:12:31 +0000   52105 execution.bulk     INFO     Processing Lines: line 118 (Process name(ForkProcess-3:3)-Process id(56258)-Line number(118)), line 119 (Process name(ForkProcess-3:2)-Process id(56252)-Line number(119)), line 120 (Process name(ForkProcess-3:1)-Process id(56247)-Line number(120)), line 121 (Process name(ForkProcess-3:4)-Process id(56265)-Line number(121)).
# 2024-09-13 18:13:00 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:2)-Process id(56252)-Line number(119) completed.
# 2024-09-13 18:13:00 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:2)-Process id(56252)-Line number(122) start execution.
# 2024-09-13 18:13:01 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:1)-Process id(56247)-Line number(120) completed.
# 2024-09-13 18:13:01 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:1)-Process id(56247)-Line number(123) start execution.
# 2024-09-13 18:13:01 +0000   52105 execution.bulk     INFO     Finished 120 / 125 lines.
# 2024-09-13 18:13:01 +0000   52105 execution.bulk     INFO     Average execution time for completed lines: 16.25 seconds. Estimated time for incomplete lines: 81.25 seconds.
# 2024-09-13 18:13:01 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:4)-Process id(56265)-Line number(121) completed.
# 2024-09-13 18:13:01 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:4)-Process id(56265)-Line number(124) start execution.
# 2024-09-13 18:13:01 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:2)-Process id(56252)-Line number(122) completed.
# 2024-09-13 18:13:01 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:1)-Process id(56247)-Line number(123) completed.
# 2024-09-13 18:13:11 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:4)-Process id(56265)-Line number(124) completed.
# 2024-09-13 18:13:31 +0000   52105 execution.bulk     INFO     [Process Pool] [Active processes: 4 / 4]
# 2024-09-13 18:13:31 +0000   52105 execution.bulk     INFO     [Lines] [Finished: 124] [Processing: 1] [Pending: 0]
# 2024-09-13 18:13:31 +0000   52105 execution.bulk     INFO     Processing Lines: line 118 (Process name(ForkProcess-3:3)-Process id(56258)-Line number(118)).
# 2024-09-13 18:14:01 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-3:3)-Process id(56258)-Line number(118) completed.
# 2024-09-13 18:14:02 +0000   52105 execution.bulk     INFO     Finished 125 / 125 lines.
# 2024-09-13 18:14:02 +0000   52105 execution.bulk     INFO     Average execution time for completed lines: 16.09 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2024-09-13 18:14:02 +0000   52105 execution.bulk     INFO     The thread monitoring the process [56247-ForkProcess-3:1] will be terminated.
# 2024-09-13 18:14:02 +0000   52105 execution.bulk     INFO     The thread monitoring the process [56258-ForkProcess-3:3] will be terminated.
# 2024-09-13 18:14:02 +0000   52105 execution.bulk     INFO     The thread monitoring the process [56252-ForkProcess-3:2] will be terminated.
# 2024-09-13 18:14:02 +0000   52105 execution.bulk     INFO     The thread monitoring the process [56265-ForkProcess-3:4] will be terminated.
# 2024-09-13 18:14:02 +0000   56258 execution.bulk     INFO     The process [56258] has received a terminate signal.
# 2024-09-13 18:14:02 +0000   56247 execution.bulk     INFO     The process [56247] has received a terminate signal.
# 2024-09-13 18:14:02 +0000   56252 execution.bulk     INFO     The process [56252] has received a terminate signal.
# 2024-09-13 18:14:02 +0000   56265 execution.bulk     INFO     The process [56265] has received a terminate signal.
# ======= Run Summary =======
#
# Run name: "promptflow_evals_evaluators_groundedness_groundedness_groundednessevaluator_6r9mrsap_20240913_174028_149507"
# Run status: "Completed"
# Start time: "2024-09-13 17:40:28.149074+00:00"
# Duration: "0:33:35.406733"
# Output path: "/home/vscode/.promptflow/.runs/promptflow_evals_evaluators_groundedness_groundedness_groundednessevaluator_6r9mrsap_20240913_174028_149507"

# %%
# Check the results using Azure AI Studio UI
if baseline_result["studio_url"]:
    print(f"Results uploaded to AI Studio {baseline_result['studio_url']}")
else:
    print("Results available at http://127.0.0.1:23333")
# Out:
# Results available at http://127.0.0.1:23333

# %% [markdown]
# #### Finetuned model evaluation metrics

# %%
pd.read_json(dataset_path_eval_answer_finetuned, lines=True).head(2)
# Out:
#                                             question  \
# 0  Is the emerging material lighter than traditio...
# 1  What type of surfing focuses on elegance and d...
#
#                                               answer  gold_final_answer  \
# 0  To answer the question, we need to identify wh...                Yes
# 1  To answer the question, we need to identify th...  Longboard surfing
#
#          final_answer                                            context
# 0                 Yes  <DOCUMENT>An emerging board material is epoxy ...
# 1  Exhibition surfing  <DOCUMENT>Done for both exhibition and competi...

# %%
finetune_result = score_dataset(dataset_path_eval_answer_finetuned, dataset_path_eval_answer_score_finetuned)
from IPython.display import display, JSON

display(JSON(finetune_result["metrics"]))
# Out:
# [2024-09-13 18:25:10 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2024-09-13 18:25:10 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2024-09-13 18:25:10 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run promptflow_evals_evaluators_similarity_similarity_similarityevaluator_yekzx791_20240913_182510_585693, log path: /home/vscode/.promptflow/.runs/promptflow_evals_evaluators_similarity_similarity_similarityevaluator_yekzx791_20240913_182510_585693/logs.txt
# [2024-09-13 18:25:10 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run promptflow_evals_evaluators_groundedness_groundedness_groundednessevaluator_dswx2cxa_20240913_182510_586583, log path: /home/vscode/.promptflow/.runs/promptflow_evals_evaluators_groundedness_groundedness_groundednessevaluator_dswx2cxa_20240913_182510_586583/logs.txt
# Prompt flow service has started...
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=promptflow_evals_evaluators_groundedness_groundedness_groundednessevaluator_dswx2cxa_20240913_182510_586583
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=promptflow_evals_evaluators_similarity_similarity_similarityevaluator_yekzx791_20240913_182510_585693
# 2024-09-13 18:56:41 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(107) completed.
# 2024-09-13 18:56:41 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(106) completed.
# 2024-09-13 18:56:41 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(110) start execution.
# 2024-09-13 18:56:41 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(111) start execution.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(108) completed.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(112) start execution.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:1)-Process id(66721)-Line number(109) completed.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:1)-Process id(66721)-Line number(113) start execution.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Finished 110 / 125 lines.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Average execution time for completed lines: 17.2 seconds. Estimated time for incomplete lines: 258.0 seconds.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(111) completed.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(114) start execution.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(110) completed.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(115) start execution.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(112) completed.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(116) start execution.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(114) completed.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(117) start execution.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(115) completed.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(118) start execution.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(116) completed.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(119) start execution.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(117) completed.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(120) start execution.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:1)-Process id(66721)-Line number(113) completed.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:1)-Process id(66721)-Line number(121) start execution.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(118) completed.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(122) start execution.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(119) completed.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(123) start execution.
# 2024-09-13 18:57:43 +0000   52105 execution.bulk     INFO     Finished 120 / 125 lines.
# 2024-09-13 18:57:43 +0000   52105 execution.bulk     INFO     Average execution time for completed lines: 16.27 seconds. Estimated time for incomplete lines: 81.35 seconds.
# 2024-09-13 18:57:52 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(123) completed.
# 2024-09-13 18:57:52 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(124) start execution.
# 2024-09-13 18:58:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(122) completed.
# 2024-09-13 18:58:43 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(120) completed.
# 2024-09-13 18:58:43 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:1)-Process id(66721)-Line number(121) completed.
# 2024-09-13 18:58:43 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(124) completed.
# 2024-09-13 18:58:43 +0000   52105 execution.bulk     INFO     Finished 125 / 125 lines.
# 2024-09-13 18:58:43 +0000   52105 execution.bulk     INFO     Average execution time for completed lines: 16.1 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2024-09-13 18:58:43 +0000   52105 execution.bulk     INFO     The thread monitoring the process [66749-ForkProcess-8:3] will be terminated.
# 2024-09-13 18:58:43 +0000   52105 execution.bulk     INFO     The thread monitoring the process [66721-ForkProcess-8:1] will be terminated.
# 2024-09-13 18:58:43 +0000   52105 execution.bulk     INFO     The thread monitoring the process [66735-ForkProcess-8:2] will be terminated.
# 2024-09-13 18:58:43 +0000   52105 execution.bulk     INFO     The thread monitoring the process [66763-ForkProcess-8:4] will be terminated.
# [2024-09-13 18:25:12 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:25:12 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:25:12 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:25:12 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:25:12 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:25:12 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:25:12 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:25:12 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:25:12 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:25:12 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:25:12 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:25:12 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:25:12 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:25:12 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:25:12 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:25:12 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:25:22 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:25:22 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:25:22 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:25:22 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:25:22 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:25:22 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:25:22 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:25:22 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:25:22 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:25:22 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:25:22 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:25:22 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:25:22 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:25:22 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:25:22 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:25:22 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:26:13 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:26:13 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:26:13 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:26:13 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:26:13 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:26:13 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:26:13 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:26:13 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:26:13 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:26:13 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:26:13 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:26:13 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:26:13 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:26:13 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:26:13 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:26:13 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:26:23 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:26:23 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:26:23 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:26:23 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:26:23 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:26:23 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:26:23 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:26:23 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:26:23 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:26:23 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:26:23 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:26:23 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:26:23 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:26:23 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:26:23 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:26:23 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:27:13 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:27:13 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:27:13 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:27:13 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:27:13 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:27:13 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:27:13 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:27:13 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:27:13 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:27:13 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:27:14 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:27:14 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:27:14 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:27:14 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:27:14 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:27:14 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:27:23 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:27:23 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:27:23 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:27:23 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:27:24 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:27:24 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:27:24 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:27:24 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:27:24 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:27:24 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:27:24 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:27:24 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:27:24 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:27:24 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:27:24 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:27:24 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:28:14 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:28:14 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:28:14 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:28:14 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:28:14 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:28:14 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:28:14 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:28:14 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:28:14 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:28:14 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:28:14 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:28:14 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:28:14 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:28:14 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:28:14 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:28:14 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:28:24 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:28:24 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:28:24 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:28:24 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:28:24 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:28:24 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:28:24 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:28:24 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:28:24 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:28:24 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:28:24 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:28:24 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:28:24 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:28:24 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:28:24 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded token rate limit of your current AIServices S0 pricing tier. Please retry after 50 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:28:24 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #1, Retry-After=50, Back off 50.0 seconds for retry.
# [2024-09-13 18:29:15 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:29:15 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #2, Retry-After=10, Back off 10.0 seconds for retry.
# [2024-09-13 18:29:15 +0000][promptflow.core._prompty_utils][ERROR] - Exception occurs: RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2023-07-01-preview have exceeded call rate limit of your current AIServices S0 pricing tier. Please retry after 10 seconds. Please contact Azure support service if you would like to further increase the default rate limit.'}}
# [2024-09-13 18:29:15 +0000][promptflow.core._prompty_utils][WARNING] - RateLimitError #0, Retry-After=10, Back off 10.0 seconds for retry.
# ...
# 2024-09-13 18:52:39 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(90) completed.
# 2024-09-13 18:52:39 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(91) completed.
# 2024-09-13 18:52:39 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(94) start execution.
# 2024-09-13 18:52:39 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(95) start execution.
# 2024-09-13 18:53:10 +0000   52105 execution.bulk     INFO     [Process Pool] [Active processes: 4 / 4]
# 2024-09-13 18:53:10 +0000   52105 execution.bulk     INFO     [Lines] [Finished: 92] [Processing: 4] [Pending: 29]
# 2024-09-13 18:53:10 +0000   52105 execution.bulk     INFO     Processing Lines: line 92 (Process name(ForkProcess-8:1)-Process id(66721)-Line number(92)), line 93 (Process name(ForkProcess-8:3)-Process id(66749)-Line number(93)), line 94 (Process name(ForkProcess-8:4)-Process id(66763)-Line number(94)), line 95 (Process name(ForkProcess-8:2)-Process id(66735)-Line number(95)).
# 2024-09-13 18:53:29 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(93) completed.
# 2024-09-13 18:53:29 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(96) start execution.
# 2024-09-13 18:53:29 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(94) completed.
# 2024-09-13 18:53:29 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(97) start execution.
# 2024-09-13 18:53:29 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(96) completed.
# 2024-09-13 18:53:29 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(98) start execution.
# 2024-09-13 18:53:39 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(95) completed.
# 2024-09-13 18:53:39 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(99) start execution.
# 2024-09-13 18:53:39 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(97) completed.
# 2024-09-13 18:53:39 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(100) start execution.
# 2024-09-13 18:54:10 +0000   52105 execution.bulk     INFO     [Process Pool] [Active processes: 4 / 4]
# 2024-09-13 18:54:10 +0000   52105 execution.bulk     INFO     [Lines] [Finished: 97] [Processing: 4] [Pending: 24]
# 2024-09-13 18:54:10 +0000   52105 execution.bulk     INFO     Processing Lines: line 92 (Process name(ForkProcess-8:1)-Process id(66721)-Line number(92)), line 98 (Process name(ForkProcess-8:3)-Process id(66749)-Line number(98)), line 99 (Process name(ForkProcess-8:2)-Process id(66735)-Line number(99)), line 100 (Process name(ForkProcess-8:4)-Process id(66763)-Line number(100)).
# 2024-09-13 18:54:29 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(100) completed.
# 2024-09-13 18:54:29 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(101) start execution.
# 2024-09-13 18:54:40 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(101) completed.
# 2024-09-13 18:54:40 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(102) start execution.
# 2024-09-13 18:54:40 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(98) completed.
# 2024-09-13 18:54:40 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(103) start execution.
# 2024-09-13 18:54:40 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(99) completed.
# 2024-09-13 18:54:40 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(104) start execution.
# 2024-09-13 18:54:40 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:1)-Process id(66721)-Line number(92) completed.
# 2024-09-13 18:54:40 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:1)-Process id(66721)-Line number(105) start execution.
# 2024-09-13 18:54:40 +0000   52105 execution.bulk     INFO     Finished 102 / 125 lines.
# 2024-09-13 18:54:40 +0000   52105 execution.bulk     INFO     Average execution time for completed lines: 17.35 seconds. Estimated time for incomplete lines: 399.05 seconds.
# 2024-09-13 18:55:10 +0000   52105 execution.bulk     INFO     [Process Pool] [Active processes: 4 / 4]
# 2024-09-13 18:55:10 +0000   52105 execution.bulk     INFO     [Lines] [Finished: 102] [Processing: 4] [Pending: 19]
# 2024-09-13 18:55:10 +0000   52105 execution.bulk     INFO     Processing Lines: line 102 (Process name(ForkProcess-8:4)-Process id(66763)-Line number(102)), line 103 (Process name(ForkProcess-8:3)-Process id(66749)-Line number(103)), line 104 (Process name(ForkProcess-8:2)-Process id(66735)-Line number(104)), line 105 (Process name(ForkProcess-8:1)-Process id(66721)-Line number(105)).
# 2024-09-13 18:55:41 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(102) completed.
# 2024-09-13 18:55:41 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(106) start execution.
# 2024-09-13 18:55:41 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(103) completed.
# 2024-09-13 18:55:41 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(107) start execution.
# 2024-09-13 18:55:41 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(104) completed.
# 2024-09-13 18:55:41 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(108) start execution.
# 2024-09-13 18:55:41 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:1)-Process id(66721)-Line number(105) completed.
# 2024-09-13 18:55:41 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:1)-Process id(66721)-Line number(109) start execution.
# 2024-09-13 18:55:41 +0000   66757 execution.bulk     INFO     The process [66757] has received a terminate signal.
# 2024-09-13 18:55:41 +0000   66731 execution.bulk     INFO     The process [66731] has received a terminate signal.
# 2024-09-13 18:55:41 +0000   66742 execution.bulk     INFO     The process [66742] has received a terminate signal.
# 2024-09-13 18:55:41 +0000   66720 execution.bulk     INFO     The process [66720] has received a terminate signal.
# 2024-09-13 18:56:10 +0000   52105 execution.bulk     INFO     [Process Pool] [Active processes: 4 / 4]
# 2024-09-13 18:56:10 +0000   52105 execution.bulk     INFO     [Lines] [Finished: 106] [Processing: 4] [Pending: 15]
# 2024-09-13 18:56:10 +0000   52105 execution.bulk     INFO     Processing Lines: line 106 (Process name(ForkProcess-8:4)-Process id(66763)-Line number(106)), line 107 (Process name(ForkProcess-8:3)-Process id(66749)-Line number(107)), line 108 (Process name(ForkProcess-8:2)-Process id(66735)-Line number(108)), line 109 (Process name(ForkProcess-8:1)-Process id(66721)-Line number(109)).
# 2024-09-13 18:56:41 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(107) completed.
# 2024-09-13 18:56:41 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(106) completed.
# 2024-09-13 18:56:41 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(110) start execution.
# 2024-09-13 18:56:41 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(111) start execution.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(108) completed.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(112) start execution.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:1)-Process id(66721)-Line number(109) completed.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:1)-Process id(66721)-Line number(113) start execution.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Finished 110 / 125 lines.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Average execution time for completed lines: 17.2 seconds. Estimated time for incomplete lines: 258.0 seconds.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(111) completed.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(114) start execution.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(110) completed.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(115) start execution.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(112) completed.
# 2024-09-13 18:56:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(116) start execution.
# 2024-09-13 18:57:10 +0000   52105 execution.bulk     INFO     [Process Pool] [Active processes: 4 / 4]
# 2024-09-13 18:57:10 +0000   52105 execution.bulk     INFO     [Lines] [Finished: 113] [Processing: 4] [Pending: 8]
# 2024-09-13 18:57:10 +0000   52105 execution.bulk     INFO     Processing Lines: line 113 (Process name(ForkProcess-8:1)-Process id(66721)-Line number(113)), line 114 (Process name(ForkProcess-8:4)-Process id(66763)-Line number(114)), line 115 (Process name(ForkProcess-8:3)-Process id(66749)-Line number(115)), line 116 (Process name(ForkProcess-8:2)-Process id(66735)-Line number(116)).
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(114) completed.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(117) start execution.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(115) completed.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(118) start execution.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(116) completed.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(119) start execution.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(117) completed.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(120) start execution.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:1)-Process id(66721)-Line number(113) completed.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:1)-Process id(66721)-Line number(121) start execution.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(118) completed.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(122) start execution.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(119) completed.
# 2024-09-13 18:57:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(123) start execution.
# 2024-09-13 18:57:43 +0000   52105 execution.bulk     INFO     Finished 120 / 125 lines.
# 2024-09-13 18:57:43 +0000   52105 execution.bulk     INFO     Average execution time for completed lines: 16.27 seconds. Estimated time for incomplete lines: 81.35 seconds.
# 2024-09-13 18:57:52 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(123) completed.
# 2024-09-13 18:57:52 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(124) start execution.
# 2024-09-13 18:58:10 +0000   52105 execution.bulk     INFO     [Process Pool] [Active processes: 4 / 4]
# 2024-09-13 18:58:10 +0000   52105 execution.bulk     INFO     [Lines] [Finished: 121] [Processing: 4] [Pending: 0]
# 2024-09-13 18:58:10 +0000   52105 execution.bulk     INFO     Processing Lines: line 120 (Process name(ForkProcess-8:4)-Process id(66763)-Line number(120)), line 121 (Process name(ForkProcess-8:1)-Process id(66721)-Line number(121)), line 122 (Process name(ForkProcess-8:3)-Process id(66749)-Line number(122)), line 124 (Process name(ForkProcess-8:2)-Process id(66735)-Line number(124)).
# 2024-09-13 18:58:42 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:3)-Process id(66749)-Line number(122) completed.
# 2024-09-13 18:58:43 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:4)-Process id(66763)-Line number(120) completed.
# 2024-09-13 18:58:43 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:1)-Process id(66721)-Line number(121) completed.
# 2024-09-13 18:58:43 +0000   52105 execution.bulk     INFO     Process name(ForkProcess-8:2)-Process id(66735)-Line number(124) completed.
# 2024-09-13 18:58:43 +0000   52105 execution.bulk     INFO     Finished 125 / 125 lines.
# 2024-09-13 18:58:43 +0000   52105 execution.bulk     INFO     Average execution time for completed lines: 16.1 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2024-09-13 18:58:43 +0000   52105 execution.bulk     INFO     The thread monitoring the process [66749-ForkProcess-8:3] will be terminated.
# 2024-09-13 18:58:43 +0000   52105 execution.bulk     INFO     The thread monitoring the process [66721-ForkProcess-8:1] will be terminated.
# 2024-09-13 18:58:43 +0000   66749 execution.bulk     INFO     The process [66749] has received a terminate signal.
# 2024-09-13 18:58:43 +0000   52105 execution.bulk     INFO     The thread monitoring the process [66735-ForkProcess-8:2] will be terminated.
# 2024-09-13 18:58:43 +0000   52105 execution.bulk     INFO     The thread monitoring the process [66763-ForkProcess-8:4] will be terminated.
# 2024-09-13 18:58:43 +0000   66721 execution.bulk     INFO     The process [66721] has received a terminate signal.
# 2024-09-13 18:58:43 +0000   66735 execution.bulk     INFO     The process [66735] has received a terminate signal.
# 2024-09-13 18:58:43 +0000   66763 execution.bulk     INFO     The process [66763] has received a terminate signal.
# ======= Run Summary =======
#
# Run name: "promptflow_evals_evaluators_groundedness_groundedness_groundednessevaluator_dswx2cxa_20240913_182510_586583"
# Run status: "Completed"
# Start time: "2024-09-13 18:25:10.585187+00:00"
# Duration: "0:33:34.070894"
# Output path: "/home/vscode/.promptflow/.runs/promptflow_evals_evaluators_groundedness_groundedness_groundednessevaluator_dswx2cxa_20240913_182510_586583"

# %% [markdown]
# Finally, let's check the results produced by the evaluate API.

# %%
# Check the results using Azure AI Studio UI
if finetune_result["studio_url"]:
    print(f"Results uploaded to AI Studio {finetune_result['studio_url']}")
else:
    print("Results available at http://127.0.0.1:23333")

# %% [markdown]
# ## Let's look at examples

# %%
df_baseline=pd.read_json(dataset_path_eval_answer_baseline, lines=True)
df_finetuned=pd.read_json(dataset_path_eval_answer_finetuned, lines=True)
df_merged=pd.merge(df_baseline, df_finetuned, on="question", suffixes=('_baseline', '_finetuned'))

# %% [markdown]
# ## Compare the metrics of the fine-tuned model against the baseline

# %%
metrics = pd.DataFrame.from_dict({"baseline": baseline_result["metrics"], "finetuned": finetune_result["metrics"]})
metrics["improvement"] = metrics["finetuned"] / metrics["baseline"]
metrics

# %%
metrics.drop("improvement", axis=1).plot.bar(rot=0)
